# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ─────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ───────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors

# %%
plants = read.csv(file="../datasets/alpineplants.csv")
names(plants)
# Out:
#  [1] "Carex.bigelowii"    "Thalictrum.alpinum" "mean_T_winter"
#  [4] "max_T_winter"       "min_T_winter"       "mean_T_summer"
#  [7] "max_T_summer"       "min_T_summer"       "light"
# [10] "snow"               "soil_moist"         "altitude"

# %%
summary(plants)
# Out:
#  Carex.bigelowii Thalictrum.alpinum mean_T_winter     max_T_winter
#  Min.   :0.000   Min.   :0.000      Min.   :-4.300   Min.   :-1.5000
#  1st Qu.:0.000   1st Qu.:0.000      1st Qu.:-2.400   1st Qu.:-0.7500
#  Median :1.000   Median :0.000      Median :-1.200   Median :-0.5000
#  Mean   :1.359   Mean   :1.224      Mean   :-1.566   Mean   :-0.4895
#  3rd Qu.:2.000   3rd Qu.:2.000      3rd Qu.:-0.850   3rd Qu.:-0.2500
#  Max.   :8.000   Max.   :9.000      Max.   :-0.300   Max.   : 4.5000
#                                     NA's   :1        NA's   :1
#   min_T_winter    mean_T_summer    max_T_summer    min_T_summer
#  Min.   :-8.750   Min.   : 8.80   Min.   :13.50   Min.   :2.250
#  1st Qu.:-5.000   1st Qu.:10.40   1st Qu.:18.00   1st Qu.:3.750
#  Median :-2.250   Median :11.10   Median :19.50   Median :4.500
#  Mean   :-3.142   Mean   :10.92   Mean   :19.81   Mean   :4.395
#  3rd Qu.:-1.750   3rd Qu.:11.50   3rd Qu.:21.50   3rd Qu.:5.000
# ...

# %%
colSums(is.na(plants))
# Out:
# Error:
#
# ! unexpected '\\' in "colSums(is.na(plants))\"

# %%
plants_clean <- plants %>%
  select(Carex.bigelowii, Thalictrum.alpinum) %>%

# %%
hist(plants$mean_T_winter)

# %%
summary(plants$Carex.bigelowii)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   0.000   1.000   1.359   2.000   8.000

# %%
plants %>%
	select(mean_T_winter) %>%
	drop_na()%>%
	ggplot(aes(x = mean_T_winter)) +
	geom_histogram() + 
	labs(title = "Distribution of Mean Temp Winter", 
		x = "Temp (C)",
		y = "Count") +
	theme_minimal()

# %%
# Out:
# Warning message:
# Continuous x aesthetic
# ℹ did you forget `aes(group = ...)`?
